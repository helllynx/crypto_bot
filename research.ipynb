# %%
import configparser

from core.binance import Binance

import pandas as pd

import seaborn as sb

# %%
config = configparser.ConfigParser()
config.read("settings.ini")

api_key = config["Binance"]["api_key"]
secret = config["Binance"]["secret"]

binance = Binance(api_key, secret)

# %%
all_tickers = binance.get_all_tickers()

# %%
len(all_tickers)
# Out:
# 1162

# %%
tick_df = pd.DataFrame(all_tickers)

# %%
tick_df.head()
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC   0.00061200              2.153       0.02862745     0.02842200
# 1   LTCBTC   0.00035500              9.758       0.00390737     0.00363800
# 2   BNBBTC  -0.00000020             -0.012       0.00171827     0.00171260
# 3   NEOBTC   0.00001000              1.038       0.00096471     0.00096200
# 4  QTUMETH  -0.00003500             -0.790       0.00446646     0.00445400
#
#     lastPrice      lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.02903200   0.69800000  0.02903500    6.39400000  0.02903600  ...
# 1  0.00399300  40.22000000  0.00399200   30.00000000  0.00399300  ...
# 2  0.00171250  12.24000000  0.00171240    4.49000000  0.00171260  ...
# 3  0.00097300   0.33000000  0.00097200  314.11000000  0.00097300  ...
# 4  0.00439300   6.68000000  0.00438400    4.42000000  0.00439200  ...
#
#     openPrice   highPrice    lowPrice           volume    quoteVolume  \
# ...

# %%
tick_df.sort_values(by='priceChangePercent', ascending=False).head()
# Out:
#       symbol priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 628  RENUSDT  0.02894000              9.917       0.30805798     0.29173000
# 608  WANUSDT  0.02720000              9.891       0.30373632     0.27490000
# 1     LTCBTC  0.00035500              9.758       0.00390737     0.00363800
# 186  WABIBTC  0.00000043              9.685       0.00000465     0.00000446
# 191   LTCBNB  0.20600000              9.685       2.26421565     2.12400000
#
#       lastPrice        lastQty    bidPrice         bidQty    askPrice  ...  \
# 628  0.32077000  1450.80000000  0.32042000  2544.70000000  0.32112000  ...
# 608  0.30220000    45.40000000  0.30200000   164.04000000  0.30310000  ...
# 1    0.00399300    40.22000000  0.00399200    30.00000000  0.00399300  ...
# 186  0.00000487    23.00000000  0.00000487  3149.00000000  0.00000488  ...
# 191  2.33300000     0.12100000  2.33000000     4.52500000  2.33300000  ...
#
# ...
